# %%
import ConfigParser
import sys
import time
import tweepy
import operator

from collections import defaultdict

config = ConfigParser.ConfigParser()
config.read('twitter.cfg')

auth = tweepy.OAuthHandler(config.get('twitter', 'consumer_key'), config.get('twitter', 'consumer_secret'))
auth.set_access_token(config.get('twitter', 'access_token'), config.get('twitter', 'access_token_secret'))

api = tweepy.API(auth)

print 'Authorized'
# Out:
# Authorized

# %%
tweets = []

screen_name = 'BarackObama'

new_tweets = api.user_timeline(screen_name = screen_name, count=200)

tweets.extend(new_tweets)

oldest_tweet = tweets[-1].id - 1

#keep grabbing tweets until there are no tweets left to grab
while len(new_tweets) > 0:
    new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest_tweet)
    tweets.extend(new_tweets)
    oldest_tweet = tweets[-1].id - 1
    
print "Found %s tweets" % (len(tweets)), 'for', screen_name
# Out:
# Found 3219 tweets for BarackObama

# %%
hashtagDict = {}
hashtagDict = defaultdict(lambda:[])

for tweet in range(0, len(tweets)):
    if tweets[tweet].entities.get('hashtags'):
        for hashtag in range(0, len(tweets[tweet].entities.get('hashtags'))):
            hashtagDict[tweets[tweet].entities.get('hashtags')[hashtag]['text']].append(tweets[tweet].id_str)

hashtagLenght = defaultdict(int)
for hashtag, list in hashtagDict.items():
    hashtagLenght[hashtag] = len(list)

sortedHashtag = sorted(hashtagLenght.items(), key=operator.itemgetter(1), reverse = True)

for set  in sortedHashtag:
    print set[0], set[1]
# Out:
# ActOnClimate 224
# RaiseTheWage 181
# OpportunityForAll 110
# GetCovered 110
# SOTU 104
# ImmigrationAction 65
# GetCoveredNow 60
# Obamacare 50
# CollegeOpportunity 44
# IranDeal 44
# ThisIsWhy 40
# LastCall2014 36
# RebuildAmerica 31
# LeadOnTrade 29
# AmericaLeads 26
# ActOnJobs 23
# ACAWorks 21
# LoveIsLove 21
# RenewUI 20
# StandWithWomen 19
# ActionSummit 19
# Selma50 19
# LoveWins 18
# CostOfInaction 18
# FamiliesSucceed 17
# TBT 17
# WomenSucceed 17
# ItsOnUs 16
# ActOnReform 15
# FairFutureNow 15
# MarchOn 15
# MadeInAmerica 14
# WhatRepealMeans 13
# PeopleOverPolitics 13
# LeadOnLeave 13
# FixOvertime 12
# ReadySetEnroll 12
# EnoughAlready 12
# 7MillionAndCounting 11
# MyBrothersKeeper 11
# ReadyToWork 11
# NetNeutrality 10
# Asegurate 10
# AmeriCorps20 8
# AffordableCare 8
# TimeToEnroll 8
# With1010 8
# BetterWithObamacare 8
# WorkingFamilies 8
# LiveTheWage 8
# ConnectEd 7
# 14DaysLeft 7
# ACA 7
# OnTheRecord 7
# ObamaTownHall 7
# OFAction 7
# Healthy2015 6
# Cybersecurity 6
# StayCovered 6
# LGBT 6
# immigration 6
# CleanWaterRules 6
# 100Challenge 6
# SwitchToClean 6
# ConnectED 5
# WHScienceFair 5
# EqualPay 5
# EqualPayNow 5
# OutInTheCold 5
# 44Turns54 5
# DegreesNotDebt 5
# OFAFellows 5
# ThrowbackThursday 5
# CleanWater 4
# BetterBroadband 4
# GimmeFive 4
# NationOfMakers 4
# NAACP106 4
# LetGirlsLearn 4
# ChampionDenier 4
# JoiningForces 4
# ThankATeacher 4
# BeatTheBuzzer 4
# MathNotMyth 4
# ScienceSaysSo 4
# CoverAmerica 4
# VRA50 4
# WorkplaceFairness 4
# InvestInUs 3
# 1is2Many 3
# HealthCareCountdown 3
# LetsMove 3
# FindYourPark 3
# YourMomCares 3
# 8Million 3
# MemorialDay 3
# USMNT 3
# BuyNowSaveLater 3
# SheBelieves 3
# OFAYearOne 3
# EasterEggRoll 3
# WithABetterWage 3
# FF 3
# WHFilmFest 3
# MLKDay 3
# ALConvention 3
# MarchMadness 3
# ADA25 3
# FairShot 3
# ClimateChangeIsReal 3
# TimeForProgress 3
# 4DaysLeft 2
# LoveYourPetDay 2
# DACAworks 2
# PutSolarOnIt 2
# LetsFetch 2
# Thanksgiving 2
# Medicare 2
# WomensHistoryMonth 2
# LaborDay 2
# OFAugust 2
# Up4Climate 2
# renewUI 2
# Cuba 2
# ScarierThanHalloween 2
# NoMoreGames 2
# CanILive 2
# climate 2
# CleanPowerPlan 2
# BetterCare 2
# OneYearNoAction 2
# TuSaludyObama 2
# CGI2014 2
# WorldCup 2
# GettingThingsDone 2
# NeverForget 2
# BigBlockOfCheeseDay 2
# FundDHS 2
# LoveisLove 2
# PuppyBowl 2
# NationalHighFiveDay 2
# ACAworks 2
# BooksForAll 2
# WHCOA 2
# HappyHalloween 2
# ItsOurInterest 2
# MyRA 2
# CIR 2
# LifeHappens 2
# ENDA 2
# EarthDay 2
# NCA2014 2
# ObamaIRL 2
# FreeCommunityCollege 2
# ReachHigher 2
# WomensEqualityDay 1
# TD4W 1
# PaycheckFairness 1
# CivilRightsAct1964 1
# Progress4Women 1
# MiddleClassTaxCuts 1
# 3daysleft 1
# RoevWade 1
# SolarJobs 1
# GroundhogDay 1
# JonVoyage 1
# NFCM 1
# ImmigrantHeritageMonth 1
# LetsDoThis 1
# WHCD 1
# NationalVolunteerWeek 1
# BBKing 1
# Leadership 1
# WhatWomenNeed 1
# LLAP 1
# ReadAcrossAmerica 1
# IDAHOT 1
# TeamCheese 1
# PresidentialTweeters 1
# GoTeamUSA 1
# AskTheSurgeonGeneral 1
# NationalIceCreamMonth 1
# askNASA 1
# NationalBestFriendsDay 1
# ClimateChange 1
# GoSolar 1
# YoEnroll 1
# WearingOrange 1
# HeadsUp4Safety 1
# FortHood 1
# PresidentsDay 1
# EarthRightNow 1
# HappyHanukkah 1
# TeamMac 1
# OpeningDay 1
# RoshHashanah 1
# USwaters 1
# YesWeTan 1
# NationalRunningDay 1
# MemorialDayWeekend 1
# MomDance 1
# healthy2015 1
# SmallBusinessWeek 1
# Grammys 1
# PunxsutawneyPhil 1
# Ferguson 1
# HappyNationalRunningDay 1
# UNGA 1
# OpportuntyForAll 1
# BetweenTwoFerns 1
# Renewable 1
# MedalOfHonor 1
# BornIn88 1
# NotMyBossBusiness 1
# HobbyLobby 1
# FlagDay 1
# Proud 1
# LaudatoSi 1
# BlackHistoryMonth 1
# BestFansInTheWorld 1
# Roe41 1
# EqualPayDay 1
# CyberMonday 1
# CharlestonShooting 1
# HappyInternationalWomensDay 1
# Bornin88 1
# HappyTeacherAppreciationDay 1
# GatorsGetCovered 1
# eatbrighter 1
# FallonTonight 1
# RuinAPixarMovie 1
# pollution 1
# TurnipForWhat 1
# CyberSummit 1
# 10DaysLeft 1
# SpotTheDenier 1
# ClimateThanks 1
# Baracketology 1
# IndependenceDay 1
# AskTheFirstLady 1
# AirFLOTUS 1
# RaisetheWage 1
# getcovered 1
# ObamaResponde 1
# HeForShe 1
# HookEmHealthcare 1
# DSCOVR 1
# 1Million600K 1
# Medicaid 1
# VAWA 1
# HappyEarthDay 1
# 1010Means 1
# 44turns54 1
# FathersDay 1
# Fast4Families 1
# PaidSickDays 1
# tbthursday 1
# HowAreYouNotOnTwitter 1
# collegein5words 1
# PovertySummit 1
# TheKidsNeedToKnow 1
# WEMatter 1
# SueLessDoMore 1
# Sochi2014 1
# 12DaysLeft 1
# smallbiz 1
# Kimmel 1
# Video 1
# ObamaOnKimmel 1
# WorldAIDSDay 1
# 2DaysLeft 1
# ProtectYourSavings 1
# AskTheWH 1
# SocialSecurity 1
# MartinLutherKingDay 1
# CostofInaction 1
# G7Summit 1
# LLWS 1
# TheWorldIsComing 1
# FOMO 1
# AVDLM 1
# USWNTParade 1
# JackieRobinsonDay 1
# GETCOVERED 1
# TeamUSA 1
# WorldAutismAwarenessDay 1
# DoYourJobHouseGOP 1
# NWHW 1
# WestWingWeek 1
# Periscope 1
# DavidLetterman 1
# DOMA 1
# USCMWinter2014 1
# ClimateFool 1
# WalkTheWalk 1
# StrongerThan 1
# 11MillionAndCounting 1
# tbt 1
# KeepingUSHealthy 1
# CollegeSigningDay 1
# YOLO 1
# BostonStrong 1
# extremeweather 1
# FlashbackFriday 1
# HappyMothersDay 1
# GotCovered 1
# 4daysleft 1
# OTD 1
# PlutoFlyby 1
# CleanAir4Kids 1
# Cosmos 1
# MonumentsMatter 1
